# %%
# %matplotlib inline
### Standard imports
import uproot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook as tqdm
### HEPKIT imports
import hepkit.hepData as hd
import hepkit.hepPlot as hp
import hepkit.hepFormat as hf
### Settings
hf.DefaultSetup()

def PrintKeys(fileName):
    for k in uproot.open(fileName).allkeys():
        print(k)
        
def OpenRoot(fileName,tree):
    rTree = uproot.open(fileName)[tree]
    df = rTree.pandas.df(['*'],flatten=False,namedecode='utf-8')
    return df

# Special trick for string columns
def decodeList(l):
    return [x.decode(encoding='UTF-8') for x in l]

# %%
dirPath = '/Users/sdporzio/Work/AlphaSource/build/'
fName1 = '4mm_2M-ev'

# %%
# # Only if new files. Open and re-save them again in h5 format (faster)

# Open root files
md1 = OpenRoot(dirPath+fName1+'.root','metadata')
tr1 = OpenRoot(dirPath+fName1+'.root','tracks_data')
ev1 = OpenRoot(dirPath+fName1+'.root','event_data')

# %%
tr1['distEnd'] = tr1.eval('sqrt(xEnd**2. + yEnd**2.)')
# tr1.query('particle_pdg!=1000020040')
# tr1.query('particle_pdg==11')

# %%
alphas = tr1.query('particle_pdg==1000020040')
alphas = alphas.query('exitedCollection==0') 

es = tr1.query('particle_pdg==11')
xs, ys, zs = [],[],[]

for i in range(len(alphas)):
    xs.append([alphas.iloc[i]['xStart'],alphas.iloc[i]['xEnd']])
    ys.append([alphas.iloc[i]['yStart'],alphas.iloc[i]['yEnd']])
    zs.append([alphas.iloc[i]['zStart'],alphas.iloc[i]['zEnd']])

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.patches import Circle, PathPatch
import mpl_toolkits.mplot3d.art3d as art3d

width = 40
length = 40
offset = 0

zlims = [-10,length-10]
xlims = [-width/2.,width/2.]
ylims = [-width/2.,width/2.]

fig = plt.figure(figsize=(8,8),facecolor='white',dpi=100)
ax = fig.add_subplot(111, projection='3d')
ax.axes.set_xlim3d(left=zlims[0], right=zlims[1]) 
ax.axes.set_ylim3d(bottom=ylims[0], top=ylims[1]) 
ax.axes.set_zlim3d(bottom=xlims[0], top=xlims[1])
p1 = Circle((0, 0), width/2., zorder=-1, alpha=0.4,color='C7')
p2 = Circle((0, 0), 25.4/2., zorder=-1, alpha=0.4,color='C0')
ax.add_patch(p1)
ax.add_patch(p2)
art3d.pathpatch_2d_to_3d(p1, z=offset, zdir="x")
art3d.pathpatch_2d_to_3d(p2, z=offset, zdir="x")
# plt.plot(es['zStart'],es['xStart'],es['yStart'],ls='',marker='o',color='C1',markersize=0.1,zorder=99)
plt.plot([0,length],[0,0],[0,0],ls='--',color='black',lw=2,zorder=99)
for i in range(len(xs)):
    plt.plot(zs[i],xs[i],ys[i],ls='-',color='cornsilk',lw=0.5,marker='o',markerfacecolor='C1',markeredgecolor='C1',markersize=1,zorder=99)
plt.show()


fig = plt.figure(figsize=(18,6),facecolor='white',dpi=100)
plt.subplot(131)
# plt.plot(es['zStart'],es['yStart'],ls='',marker='o',color='C1',markersize=0.02,zorder=99)
for i in range(len(xs)):
    plt.plot(zs[i],ys[i],ls='-',color='cornsilk',lw=0.5,marker='o',markerfacecolor='C1',markeredgecolor='C1',markersize=1)
plt.plot([offset,offset],[-width/2.,width/2.],color='C7',lw=5,alpha=0.4,ls='-')
plt.plot([offset,offset],[-25.4/2.,25.4/2.],color='C0',lw=5,alpha=0.4,ls='-')
plt.xlim(zlims)
plt.ylim(ylims)
plt.axhline(0,ls='--',color='black',lw=2)
plt.subplot(132)
# plt.plot(es['zStart'],es['xStart'],ls='',marker='o',color='C1',markersize=0.02,zorder=99)
for i in range(len(xs)):
    plt.plot(zs[i],xs[i],ls='-',color='cornsilk',lw=0.5,marker='o',markerfacecolor='C1',markeredgecolor='C1',markersize=1)
plt.plot([offset,offset],[-width/2.,width/2.],color='C7',lw=5,alpha=0.4,ls='-')
plt.plot([offset,offset],[-25.4/2.,25.4/2.],color='C0',lw=5,alpha=0.4,ls='-')
plt.xlim(zlims)
plt.ylim(xlims)
plt.axhline(0,ls='--',color='black',lw=2)
plt.subplot(133)
# plt.plot(es['xStart'],es['yStart'],ls='',marker='o',color='C1',markersize=0.02,zorder=99)
for i in range(len(xs)):
    plt.plot(xs[i],ys[i],ls='-',color='cornsilk',lw=0.5,marker='o',markerfacecolor='C1',markeredgecolor='C1',markersize=1)
plt.scatter(0,0,color='black',s=100)
ax = plt.gca()
t1 = Circle((0, 0), width/2., zorder=-1, alpha=0.4,color='C7')
t2 = Circle((0, 0), 25.4/2., zorder=-1, alpha=0.4,color='C0')
ax.add_patch(t1)
ax.add_patch(t2)
plt.xlim(xlims)
plt.ylim(ylims)
plt.show()

# %%
nbins=20

fig = plt.figure(figsize=(12,6),facecolor='white',dpi=100)
plt.subplot(121)
hp.HepHist(alphas['xStart'],nbins=nbins,xlims=xlims,color='darkblue',label='Start point')
hp.HepHist(alphas['xEnd'],nbins=nbins,xlims=xlims,color='C0',label='End point')
plt.axvline(0,ls='--',lw=5,color='black',zorder=-1,label='Anode')
plt.grid(ls='--',color='C7',alpha=0.1)
plt.legend(bbox_to_anchor=(0, -0.15, 1, 0), loc=2, ncol=2, mode="expand", borderaxespad=0, frameon=False)
plt.xlabel('X coordinate [mm]')

plt.subplot(122)
hp.HepHist(alphas['yStart'],nbins=nbins,xlims=ylims,color='saddlebrown',label='Start point')
hp.HepHist(alphas['yEnd'],nbins=nbins,xlims=ylims,color='C1',label='End point')
plt.axvline(0,ls='--',lw=5,color='black',zorder=-1,label='Anode')
plt.grid(ls='--',color='C7',alpha=0.1)
plt.legend(bbox_to_anchor=(0, -0.15, 1, 0), loc=2, ncol=2, mode="expand", borderaxespad=0, frameon=False)
plt.xlabel('Y coordinate [mm]')

plt.show()

# %%
nbins=50

fig = plt.figure(figsize=(10,6),facecolor='white',dpi=100)
mean = alphas['distEnd'].mean()
std = alphas['distEnd'].std()
hp.HepHist(alphas['distEnd'],nbins=nbins,xlims=[0,30],color='C0')
plt.axvline(mean,ls='--',lw=5,color='darkblue',label=f'Mean: {mean:.1f}'+r' $\pm$ '+f'{std:.1f} mm')
plt.axvline(mean+std,ls=':',lw=1,color='darkblue')
plt.axvline(mean-std,ls=':',lw=1,color='darkblue')
plt.grid(ls='--',color='C7',alpha=0.1)
plt.legend(bbox_to_anchor=(0, -0.15, 1, 0), loc=2, ncol=2, mode="expand", borderaxespad=0, frameon=False)
plt.xlabel('End coordinate 3D distance from anode [mm]')

plt.show()

# %%
from scipy import interpolate
xs = [0,1,15]
ys = [0,1/1.3,15/0.8]
eTime = interpolate.interp1d(xs, ys, kind='quadratic', fill_value='extrapolate')

def distToAx(vec):
    return np.sqrt(vec[0]**2.+vec[1]**2.)

time = []
for i in range(len(alphas)):
    # For each alpha, take start and end point
    s = np.array([alphas.iloc[0]['xStart'],alphas.iloc[0]['yStart'],0])
    e = np.array([alphas.iloc[0]['xEnd'],alphas.iloc[0]['yEnd'],alphas.iloc[0]['zEnd']])
    # Get direction vector
    shiftV = e - s
    normV = np.sqrt(shiftV[0]**2 + shiftV[1]**2 + shiftV[2]**2)
    dirV = shiftV/normV
    
    for j in range()

s = np.array([alphas.iloc[0]['xStart'],alphas.iloc[0]['yStart'],0])
e = np.array([alphas.iloc[0]['xEnd'],alphas.iloc[0]['yEnd'],alphas.iloc[0]['zEnd']])
shiftV = e - s
normV = np.sqrt(shiftV[0]**2 + shiftV[1]**2 + shiftV[2]**2)
dirV = shiftV/normV
steps = int(np.ceil(normV))
# dirV
xs,ys,zs = [],[],[]
for i in range(steps+1):
    vecLoc = dirV*i + s
    dist = distToAx(vecLoc)
    time = eTime(dist)
    print(time)
    

fig = plt.figure(figsize=(8,8),facecolor='white',dpi=100)
ax = fig.add_subplot(111, projection='3d')
plt.plot([s[2],e[2]],[s[1],e[1]],[s[0],e[0]],marker='o')
plt.plot(zs,ys,xs,ls='',marker='o')
plt.show()
# Out:
# 15.190780879511088
# 15.735534522613122
# 16.28815537431923
# 16.848636556987767
# 17.41697183618906
# 17.99315554746613
# 18.57718253284926
# 19.16904808564657
# 19.768747902282016
# 20.376278040156198
# 20.991634880671327
# 21.614815096698717
# 22.245815623879764
# 22.88463363524472
# 23.531266518711316
# 24.18571185708975
# 24.847967410275096
# 25.518031099353344
# 26.195900992385937

# %%
nbins=50

mean = alphas['tEnd'].mean()
std = alphas['tEnd'].std()
fig = plt.figure(figsize=(10,6),facecolor='white',dpi=100)
hp.HepHist(alphas['tEnd'],nbins=nbins,xlims=[0,5],color='C0')
plt.axvline(mean,ls='--',lw=5,color='darkblue',label=f'Mean: {mean:.1f}'+r' $\pm$ '+f'{std:.1f} ns')
plt.axvline(mean+std,ls=':',lw=1,color='darkblue')
plt.axvline(mean-std,ls=':',lw=1,color='darkblue')
plt.grid(ls='--',color='C7',alpha=0.1)
plt.legend(bbox_to_anchor=(0, -0.15, 1, 0), loc=2, ncol=2, mode="expand", borderaxespad=0, frameon=False)
plt.xlabel('Time for alpha to cross chamber [ns]')
plt.show()
